# %%
import h5py
import os
os.chdir("..")
os.getcwd()
# Out:
# 'c:\\Users\\madha\\vsCode\\Github\\pathointelligence'

# %%
y_path = "Data/raw/camelyonpatch_level_2_split_train_y.h5"

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\madha\\vsCode\\Github\\pathointelligence\\notebooks'

# %%
y_file = h5py.File(y_path, "r")
# Out:
# <HDF5 file "camelyonpatch_level_2_split_train_y.h5" (mode r)>

# %%
keys = list(y_file.keys())
keys
# Out:
# ['y']

# %%
y_file[keys[0]]
# Out:
# <HDF5 dataset "y": shape (262144, 1, 1, 1), type "|u1">

# %%
x_path = "Data/raw/camelyonpatch_level_2_split_train_x.h5"

# %%
x_file = h5py.File(x_path, "r")
x_file.keys()
# Out:
# <KeysViewHDF5 ['x']>

# %%
x_file['x'][1].shape
# Out:
# (96, 96, 3)

# %%
val_1 = y_file['y'][1]

# %%
val_1.shape
# Out:
# (1, 1, 1)

# %%
type(val_1)
val_1.reshape(-1)[0]
# Out:
# np.uint8(1)
